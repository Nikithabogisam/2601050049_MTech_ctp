# %%
numbers = list(map(int, input("Enter numbers separated by spaces: ").split()))

current_sum = numbers[0]
maximum_sum = numbers[0]

start = 0
best_start = 0
best_end = 0

for i in range(1, len(numbers)):
    if numbers[i] > current_sum + numbers[i]:
        current_sum = numbers[i]
        start = i
    else:
        current_sum = current_sum + numbers[i]

    if current_sum > maximum_sum:
        maximum_sum = current_sum
        best_start = start
        best_end = i

best_subarray = numbers[best_start:best_end + 1]

print("Original list:", numbers)
print("Maximum subarray:", best_subarray)
print("Maximum sum:", maximum_sum)
# Out:
# Enter numbers separated by spaces:  1 21 31 2 7 3 8 14
# Original list: [1, 21, 31, 2, 7, 3, 8, 14]
# Maximum subarray: [1, 21, 31, 2, 7, 3, 8, 14]
# Maximum sum: 87
