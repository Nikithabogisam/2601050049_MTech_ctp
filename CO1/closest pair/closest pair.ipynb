# %%
import math

students = []

n = int(input("Enter number of students: "))

for i in range(n):
    name = input("Enter student name: ")
    x = float(input("Enter X coordinate: "))
    y = float(input("Enter Y coordinate: "))

    students.append((name, x, y))

minimum_distance = float("inf")
student1 = ""
student2 = ""

for i in range(n):
    for j in range(i + 1, n):
        x1 = students[i][1]
        y1 = students[i][2]

        x2 = students[j][1]
        y2 = students[j][2]

        distance = math.sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2)

        if distance < minimum_distance:
            minimum_distance = distance
            student1 = students[i][0]
            student2 = students[j][0]

print("\n--- CLOSEST STUDENTS ---")
print("Students:", student1, "and", student2)
print("Distance:", round(minimum_distance, 2))
# Out:
# Enter number of students:  3
# Enter student name:  nikitha
# Enter X coordinate:  2
# Enter Y coordinate:  3
# Enter student name:  jyothi
# Enter X coordinate:  7
# Enter Y coordinate:  5
# Enter student name:  devi
# Enter X coordinate:  4
# Enter Y coordinate:  9
# --- CLOSEST STUDENTS ---
# Students: jyothi and devi
# Distance: 5.0
